# %%
import pandas as pd
import numpy as np
import re

### 한국자막 df 만들기
url_kor = pd.read_csv("URL_KOREAN.csv").drop('ȸ', axis=1)
final_data = pd.DataFrame()

for k in range(100):
    f = open("C:/Users/kdg95/Desktop/lang/python/tobigs project/Korean_sub_srt/"+str(k)+"회.srt",'r',encoding='UTF8')
    lines = f.readlines()
    f.close()
    
    srt = []
    for i in range(len(lines)):
        srt += {lines[i].replace('\n','')}
    
    time = []
    subtitle = []
    time_re = re.compile('..:..:..')
    sub_re = re.compile('[가-힣a-zA-Z]')
    space_re = re.compile(' ')
    for i in range(len(srt)):
        if time_re.search(srt[i]) :
            time += [{'time' : srt[i]}]
        elif sub_re.search(srt[i]) :
            if sub_re.search(srt[i-1]) :
                next
            elif sub_re.search(srt[i+1]) :
                subtitle += [{'subtitle' : srt[i] + ' ' + srt[i+1]}]
                next
            else :
                subtitle += [{'subtitle' : srt[i]}]
        elif space_re.match(srt[i]):
            subtitle += [{'subtitle' : srt[i]}]
            next
                
    start = []
    end = []
    for i in range(len(time)):
        a = list(time[i].values())[0]
        b = a.split(' ')
        start += [{'start' : b[0]}]
        end += [{'end' : b[2]}]
        
    url = []
    for i in range(len(subtitle)):
        url += [{'url' : url_kor['URL'][k]}]
    
    data = pd.concat([pd.DataFrame(url), pd.DataFrame(start), pd.DataFrame(end), pd.DataFrame(subtitle)], axis = 1).iloc[:-1,]
    final_data = pd.concat([final_data, data], axis = 0)

final_data = final_data.loc[final_data['subtitle'] != ' ',:]
final_data.to_csv('kor_sub.csv',encoding='UTF8')

### 영어 자막 df 만들기
url_eng = pd.read_csv("data/english_sub.csv").drop('Unnamed: 0', axis=1)
final_data2 = pd.DataFrame()

for k in range(1,101):
    f = open("C:/Users/kdg95/Desktop/lang/python/tobigs project/english_sub/english_sub/"+str(k)+".srt",'r',encoding='UTF8')
    lines = f.readlines()
    f.close()
    
    srt = []
    for i in range(len(lines)):
        srt += {lines[i].replace('\n','')}
    
    time = []
    subtitle = []
    time_re = re.compile('..:..:..')
    sub_re = re.compile('[가-힣a-zA-Z]')
    space_re = re.compile(' ')
    for i in range(len(srt)):
        if time_re.search(srt[i]) :
            time += [{'time' : srt[i]}]
        elif sub_re.search(srt[i]) :
            if q.search(srt[i-1]) :
                next
            elif sub_re.search(srt[i+1]) :
                subtitle += [{'subtitle' : srt[i] + ' ' + srt[i+1]}]
                next
            else :
                subtitle += [{'subtitle' : srt[i]}]
        elif space_re.match(srt[i]):
            subtitle += [{'subtitle' : srt[i]}]
            next
                
    start = []
    end = []
    for i in range(len(time)):
        a = list(time[i].values())[0]
        b = a.split(' ')
        start += [{'start' : b[0]}]
        end += [{'end' : b[2]}]
        
    url = []
    for i in range(len(subtitle)):
        url += [{'url' : url_eng['url'][k-1]}]
    
    data = pd.concat([pd.DataFrame(url), pd.DataFrame(start), pd.DataFrame(end), pd.DataFrame(subtitle)], axis = 1).iloc[:-1,]
    final_data2 = pd.concat([final_data2, data], axis = 0)

final_data2 = final_data2.loc[final_data2['subtitle'] != ' ',:]
final_data2.to_csv('data/eng_sub.csv',encoding='UTF8')

# %%
pd.read_csv("data/kor_sub.csv")
# 26430         333  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26431         334  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26432         335  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26433         336  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26434         337  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26435         338  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26436         339  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26437         340  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26438         341  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26439         342  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26440         343  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26441         344  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26442         345  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26443         346  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26444         347  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
# 26445         348  https://www.youtube.com/watch?v=rxOz8PV_d50&li...
#
#               start           end                              subtitle
# 0      00:00:14,117  00:00:20,096                              (박수와 환호)
# 1      00:00:20,096  00:00:25,820                     반갑습니다 오우~ 너무 반가워요
# 2      00:00:25,820  00:00:29,656     자리가 없으셔서 여기에 이렇게 VVIP 석에 앉으신 거에요?
# 3      00:00:29,656  00:00:36,508       15분이라는 시간이 있으니까 조금 마음이 더 긴장이 되고
# 4      00:00:36,508  00:00:38,803                좀 컴팩트하게 여러분께 짧은 시간에 뭔가
# 5      00:00:38,803  00:00:42,763               많이 전해드려야 되는데 라는 생각이 드는데
# 6      00:00:42,763  00:00:44,952                         그냥 저는 편하게 할게요
# 7      00:00:44,952  00:00:48,742                저는 라디오 하듯이 15분 쉬었다 가세요
# 8      00:00:48,742  00:00:51,101                  그냥 그런 쉬는 얘기를 하려고 왔어요
# 9      00:00:51,101  00:00:54,101                  오늘 스트레스에 관련된 얘기를 하면서
# 10     00:00:54,101  00:00:58,424  제가 마음의 안전이라고 여기서 아주 멋진 제목을 붙여 주시더라고요
# 11     00:00:58,424  00:01:00,102                       좋은 것 같아요 마음의 안전
# 12     00:01:00,102  00:01:03,493             근데 마음이라는 것이 우리 오장육부 장기중에서
# 13     00:01:03,493  00:01:06,493                유일하게 내 마음대로 안 되는, 그렇죠?
# 14     00:01:06,493  00:01:08,476                         마음이 바로 여기 있는데
# 15     00:01:08,476  00:01:11,336                   정말 너무나 먼 거리에 있는 것처럼
# 16     00:01:11,336  00:01:15,846           통제가 안 되는 순간들을  매일 겪잖아요, 매순간
# 17     00:01:15,846  00:01:20,551  여기 저 만나러, 다른 분들 만나러 오시는 이 길, 오는 이 길에
# 18     00:01:20,551  00:01:24,640            여러분이 확 돌아버릴 만한 사건 사고 없었나요?
# 19     00:01:24,640  00:01:27,640                       있었죠? 일단 교통 그렇죠?
# 20     00:01:27,640  00:01:29,329                       지하철 타고 오신 분들이어도
# 21     00:01:29,329  00:01:33,449         지하철 내에서 충분히 그런 경험을 맞닥뜨릴 수 있어요
# 22     00:01:33,449  00:01:34,564                             스트레스 같은 거
# 40770  01:20:19,766  01:20:22,933
# 40771  01:20:40,233  01:20:44,248
# 40772  01:20:44,248  01:20:47,695
# 40773  01:20:47,695  01:20:50,633
# 40774  01:20:50,633  01:20:53,843
# 40775  01:20:53,843  01:20:57,156
# 40776  01:20:57,156  01:21:00,313
# 40777  01:21:00,313  01:21:03,353
# 40778  01:21:03,353  01:21:06,516
# 40779  01:21:06,516  01:21:09,845
# 40780  01:21:09,845  01:21:13,492
# 40781  01:21:13,492  01:21:15,825
# 40782  01:21:18,255  01:21:20,087
# 40783  01:21:20,087  01:21:21,004
# 40784  01:21:21,868  01:21:23,673
# 40785  01:21:23,673  01:21:26,095
# 40786  01:21:26,095  01:21:28,175
# 40787  01:21:28,175  00:00:00,000
#
#                                                 subtitle
# 0      Thanks to Curiosity Stream for supporting Cras...
# 1                                                 Hello!
# 2      As you might have noticed, I’m not Craig or Lily.
# 3      My name’s Michael Aranda, and I’ll be your hos...
# 4      Now, since we’re getting to know each other, l...
# 5      Maybe there’s a movie that makes you wanna get...
# 6      Or maybe you love anything that Zoe Saldana is...
# 7      Films can have an awesome story or sloppy ligh...
# 8                  who are just straight-up stereotypes.
# 9      All these things can affect how you feel about...
# 10            up on Netflix… because that’s a thing now.
# 11     But they can also affect how it fits into cine...
# 12     We’ll think critically about a lot of very dif...
# 13     with an American classic that many people call...
# 14     It came from ambition and some unusual circums...
# 15     And even though it’s been a long time since it...
# 16     cleverness and story still resonate with audie...
# 17           I’m talking, of course, about Citizen Kane.
# 18                                   [Intro Music Plays]
# 19     Calling Citizen Kane one of the best films of ...
# 20     To be honest, the idea of ranking movies and m...
# 21              not what film criticism is really about.
# 22     It’s about thinking deeply about how the movie...
# 23                       and within history and society.
# 24     It’s about understanding, deconstructing, feel...
# 25     So is Citizen Kane the “Greatest Movie Ever Ma...
# 26     Well, we can’t answer that, because it’s not t...
# 27     But there’s clearly something about it that st...
# 28         And maybe that something is its origin story.
# 29     Orson Welles was hoisted into the spotlight at...
# ...                                                  ...
# 40758            And my answer is somewhat embarrassing,
# 40759  which is that we've only run this method on tw...
# 40760         so we actually don't have a good idea yet.
# 40761   But I think it's something interesting to study.
# 40762  If I remember correctly, my coauthors open sou...
# 40763           So you could probably run it on ImageNet
# 40764                          without too much trouble.
# 40765               My contribution to that paper was in
# 40766                     the week that I was unemployed
# 40767   between working at OpenAI and working at Google,
# 40768                         so I had access to no GPUS
# 40769     and I ran that experiment on my laptop on CPU,
# 40770     so it's only really small datasets. [chuckles]
# 40771                              [speaker drowned out]
# 40772    Oh, so the question is, do we end up perturbing
# 40773  clean examples to low confidence adversarial e...
# 40774             Yeah, in practice we usually find that
# 40775  we can get very high confidence on the output ...
# 40776  One thing in high dimensions that's a little b...
# 40777                is that just getting the sign right
# 40778                   on very many of the input pixels
# 40779         is enough to get a really strong response.
# 40780             So the angle between the weight vector
# 40781      matters a lot more than the exact coordinates
# 40782                       in high dimensional systems.
# 40783                       Does that make enough sense?
# 40784                                        Yeah, okay.
# 40785      - [Man] So we're actually going to [mumbles].
# 40786         So if you guys need to leave, that's fine.
# 40787          But let's thank our speaker one more time
#
# [40788 rows x 5 columns]
